# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwinperti/Assignment-2-Cyber-Security-/blob/master/ATAL_KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
d = load_iris()

# %%
X = d['data']
y = d['target']
col_names = d['feature_names']

# %%
df = pd.DataFrame(X, columns=col_names)

# %%
fig, ax = plt.subplots()
colors = ['red','blue','green']
for i in range(3):
  df[y==i].plot(kind='scatter',x='sepal length (cm)', y='sepal width (cm)',ax=ax,c=colors[i],label=f'Class {i}')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
n_neighbors = 2
iris = load_iris()

# we only take the first two features. We could avoid this ugly
# slicing by using a two-dim dataset
X = iris.data[:, :2]
y = iris.target

h = .02  # step size in the mesh

# Create color maps
cmap_light = ListedColormap(['orange', 'cyan', 'cornflowerblue'])
cmap_bold = ['darkorange', 'c', 'darkblue']

for n_neighbors in [1, 2, 3, 4, 5, 10, 20]:
    # we create an instance of Neighbours Classifier and fit the data.
    clf = neighbors.KNeighborsClassifier(n_neighbors)
    clf.fit(X, y)

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure(figsize=(8, 6))
    plt.contourf(xx, yy, Z, cmap=cmap_light)

    # Plot also the training points
    sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=iris.target_names[y],
                    palette=cmap_bold, alpha=1.0, edgecolor="black")
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title("3-Class classification (k = %i)"
              % (n_neighbors))
    plt.xlabel(iris.feature_names[0])
    plt.ylabel(iris.feature_names[1])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(n_neighbors=2)
clf.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                      weights='uniform')

# %%
clf.predict([[4.5, 5]])
# Out:
# array([0])

# %%
df = pd.DataFrame({"age":[10, 11, 10, 10.5, 11.5, 12], "hours":[30, 3, 45, 9, 6, 43 ]})

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
df.plot(kind='scatter',x='age',y='hours',ax=ax)

# %%
df
# Out:
#     age  hours
# 0  10.0     30
# 1  11.0      3
# 2  10.0     45
# 3  10.5      9
# 4  11.5      6
# 5  12.0     43

# %%
df = (df - df.mean())/df.std()

# %%
df
# Out:
#         age     hours
# 0 -1.020621  0.384653
# 1  0.204124 -1.031569
# 2 -1.020621  1.171443
# 3 -0.408248 -0.716853
# 4  0.816497 -0.874211
# 5  1.428869  1.066538

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
df.plot(kind='scatter',x='age',y='hours',ax=ax)

# %%
import numpy as np

sample = np.random.choice(range(10, 50), size=1000)

# %%
plt.boxplot(sample)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f11dccc8f28>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f11e0ccecf8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f11e0e152b0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f11e0e15080>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f11dcb74198>,
#   <matplotlib.lines.Line2D at 0x7f11e0ccef60>]}

# %%
sns.violinplot(sample)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.hist(sample)
# Out:
# (array([103., 113.,  94., 112.,  94., 101.,  90., 110.,  91.,  92.]),
#  array([10. , 13.9, 17.8, 21.7, 25.6, 29.5, 33.4, 37.3, 41.2, 45.1, 49. ]),
#  <a list of 10 Patch objects>)
